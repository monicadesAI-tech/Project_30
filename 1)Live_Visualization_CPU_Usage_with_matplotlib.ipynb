# %% [markdown]
# # Plotting/Visualizing Real-Time CPU Usage in Python

# %%
# You can also install libraries in virtual environment so that you donot have to install everytime you access file.

# %%
# !pip install psutil

# %%
import time 
import psutil
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
plt.rcParams['animation.html'] = 'jshtml'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
psutil.cpu_percent()
# Out:
# 25.4

# %%
i = 0
x, y = [], []
while True:
    x.append(i)
    y.append(psutil.cpu_percent())
    
    ax.plot(x,y,color='b')
    
    fig.canvas.draw()
    
    ax.set_xlim(left=max(0,i-50),right = i+50)  # To get live data only and not old, if you want old data also then remove this line
    
    time.sleep(0.1)
    i += 1

# %%
plt.close()
